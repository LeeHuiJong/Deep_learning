# %%
! git clone https://github.com/LeeHuiJong/-Deep_learning
# Out:
# Cloning into '-Deep_learning'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 57 (delta 21), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (57/57), done.

# %%
import sys
sys.path.append('/content/-Deep_learning/00.추가학습/data')

# %%
from detect_with_yolo import *

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights -O yolov3.weights
# Out:
# --2022-06-22 05:06:33--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  20.7MB/s    in 12s
#
# 2022-06-22 05:06:46 (19.2 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
weight_file= 'yolov3.weights'
cfg_file = '/content/SkillTreePython-DeepLearning/data/yolov3.cfg'
name_file = '/content/SkillTreePython-DeepLearning/data/coco.names'

model, predict_layer_names = set_model(weight_file, cfg_file)
class_names, class_colors = set_label(name_file)

# %%
img_path = 'road.jpg' #@param ['withanimals.jpg', 'withanimals2.jpg', 'road_withanimals.jpg', 'road_withanimals2.jpg', 'road.jpg'] 
img_path = f'/content/SkillTreePython-DeepLearning/data/{img_path}'
img = cv2.imread(img_path)
img2detect(img, model, predict_layer_names, class_names, class_colors)
# Out:
# <PIL.Image.Image image mode=RGB size=256x197 at 0x7F9836120C90>
