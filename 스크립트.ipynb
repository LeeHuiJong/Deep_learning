# %% [markdown]
# <a href="https://colab.research.google.com/github/LeeHuiJong/-Deep_learning/blob/main/%EC%8A%A4%ED%81%AC%EB%A6%BD%ED%8A%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 세팅

# %%
! git clone https://github.com/LeeHuiJong/-Deep_learning
# Out:
# fatal: destination path '-Deep_learning' already exists and is not an empty directory.

# %%
import sys
sys.path.append('/content/-Deep_learning/00.추가학습/data')

# %%
from detect_plate import *

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights -O yolov3.weights
# Out:
# --2022-06-22 05:41:06--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  97.5MB/s    in 2.4s
#
# 2022-06-22 05:41:09 (97.5 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
weight_file= 'yolov3.weights'
cfg_file = '/content/-Deep_learning/00.추가학습/data/yolov3.cfg'
name_file = '/content/-Deep_learning/00.추가학습/data/coco.names'

model, predict_layer_names = set_model(weight_file, cfg_file)
class_names, class_colors = set_label(name_file)

# %% [markdown]
# ## 함수 사용 및 결과 출력

# %%
img_path = '/content/-Deep_learning/00.추가학습/data/car4.jpg'
img = cv2.imread(img_path)
img2detect(img, model, predict_layer_names)
# Out:
# <PIL.Image.Image image mode=RGB size=500x375 at 0x7F47548BEC50>
