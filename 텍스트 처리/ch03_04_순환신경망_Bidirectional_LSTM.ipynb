# %% [markdown]
# <a href="https://colab.research.google.com/github/yebiny/SkillTreePython-DeepLearning/blob/main/03.NLP-with-tensorflow2.0/ch03_04_%EC%88%9C%ED%99%98%EC%8B%A0%EA%B2%BD%EB%A7%9D_Bidirectional_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ch03.04_순환신경망 - Bidirectional-LSTM
# ---
#
# * 날짜:
# * 이름:
#
#
# ## 학습내용
#     - 순환 신경망에 대해 이해한다.
#     - BiLSTM
#     - 로이터 뉴스기사 카테고리 분류
#     - 스팀 리뷰 걈성 분류

# %% [markdown]
# ```
# ! git clone https://github.com/yebiny/SkillTreePython-DeepLearning
# ```

# %%
! git clone https://github.com/yebiny/SkillTreePython-DeepLearning
# Out:
# Cloning into 'SkillTreePython-DeepLearning'...
# remote: Enumerating objects: 735, done.
# remote: Counting objects: 100% (308/308), done.
# remote: Compressing objects: 100% (152/152), done.
# remote: Total 735 (delta 187), reused 255 (delta 155), pack-reused 427
# Receiving objects: 100% (735/735), 38.42 MiB | 21.83 MiB/s, done.
# Resolving deltas: 100% (380/380), done.

# %% [markdown]
# ```
# import sys
# sys.path.append('/content/SkillTreePython-DeepLearning/scripts')
# from import_lib import *
# from plot_result import *
# ```

# %%
import sys
sys.path.append('/content/SkillTreePython-DeepLearning/scripts')
from import_lib import *
from plot_result import *

# %% [markdown]
# ## 로이터 뉴스 기사 분류
# ---

# %% [markdown]
# ### | 데이터 전처리

# %% [markdown]
# #### **데이터 불러오기**

# %%
MAX_FEATURES = 1000 # 데이터에 1000(-1)개 단어만 포함하기
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.reuters.load_data(num_words = MAX_FEATURES)
print('훈련데이터 :', x_train.shape, y_train.shape)
print('테스트데이터 :', x_test.shape, y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2113536/2110848 [==============================] - 0s 0us/step
# 2121728/2110848 [==============================] - 0s 0us/step
# 훈련데이터 : (8982,) (8982,)
# 테스트데이터 : (2246,) (2246,)

# %% [markdown]
# #### **데이터 확인**

# %%
print('첫번째 기사:', x_train[0]) # 토큰화, 단어 인덱싱 된 상태
print('첫번째 기사의 카테고리:', y_train[0])
print('카테고리 개수:', np.max(y_train)+1) # 클래스가 0~45
# Out:
# 첫번째 기사: [1, 2, 2, 8, 43, 10, 447, 5, 25, 207, 270, 5, 2, 111, 16, 369, 186, 90, 67, 7, 89, 5, 19, 102, 6, 19, 124, 15, 90, 67, 84, 22, 482, 26, 7, 48, 4, 49, 8, 864, 39, 209, 154, 6, 151, 6, 83, 11, 15, 22, 155, 11, 15, 7, 48, 9, 2, 2, 504, 6, 258, 6, 272, 11, 15, 22, 134, 44, 11, 15, 16, 8, 197, 2, 90, 67, 52, 29, 209, 30, 32, 132, 6, 109, 15, 17, 12]
# 첫번째 기사의 카테고리: 3
# 카테고리 개수: 46

# %%
word2index = tf.keras.datasets.reuters.get_word_index()
print(index2word)
# Out:
# {'mdbl': 10996, 'fawc': 16260, 'degussa': 12089, 'woods': 8803, 'hanging': 13796, 'localized': 20672, 'sation': 20673, 'chanthaburi': 20675, 'refunding': 10997, 'hermann': 8804, 'passsengers': 20676, 'stipulate': 20677, 'heublein': 8352, 'screaming': 20713, 'tcby': 16261, 'four': 185, 'grains': 1642, 'broiler': 20680, 'wooden': 12090, 'wednesday': 1220, 'highveld': 13797, 'duffour': 7593, '0053': 20681, 'elections': 3914, '270': 2563, '271': 3551, '272': 5113, '273': 3552, '274': 3400, 'rudman': 7975, '276': 3401, '277': 3478, '278': 3632, '279': 4309, 'dormancy': 9381, 'errors': 7247, 'deferred': 3086, 'sptnd': 20683, 'cooking': 8805, 'stratabit': 20684, 'designing': 16262, 'metalurgicos': 20685, 'databank': 13798, '300er': 20686, 'shocks': 20687, 'nawg': 7972, 'tnta': 20688, 'perforations': 20689, 'affiliates': 2891, '27p': 20690, 'ching': 16263, 'china': 595, 'wagyu': 16264, 'affiliated': 3189, 'chino': 16265, 'chinh': 16266, 'slickline': 20692, 'doldrums': 13799, 'kids': 12092, 'climbed': 3028, 'controversy': 6693, 'kidd': 20693, 'spotty': 12093, 'rebel': 12639, 'millimetres': 9382, 'golden': 4007, 'projection': 5689, 'stern': 12094, "hudson's": 7903, 'dna': 10066, 'dnc': 20695, 'hodler': 20696, 'lme': 2394, 'insolvancy': 20697, 'music': 13800, 'therefore': 1984, 'dns': 10998, 'distortions': 6959, 'thassos': 13801, 'populations': 20698, 'meteorologist': 8806, 'loss': 43, 'exco': 9383, 'adventist': 20813, 'murchison': 16267, 'locked': 10999, 'kampala': 13802, 'arndt': 20699, 'nakasone': 1267, 'steinweg': 20700, "india's": 3633, 'wang': 3029, 'wane': 10067, 'unjust': 13803, 'titanium': 13804, 'want': 850, 'pinto': 20701, "institutes'": 16268, 'absolute': 7973, 'travel': 4677, 'cutback': 6422, 'nazmi': 16269, 'modest': 1858, 'shopwell': 16270, 'sedi': 20702, 'adoped': 20703, 'tulis': 16271, '18th': 20704, "wmc's": 20705, 'menlo': 20706, 'reiners': 11000, 'farmlands': 12095, 'nonsensical': 20707, 'elisra': 20708, 'welcomed': 2461, 'peup': 20709, "holiday's": 16272, 'activating': 20711, 'avondale': 16273, 'interational': 16274, 'welcomes': 20712, 'fip': 16275, 'tailings': 11001, 'fit': 4205, 'lifeline': 16276, 'bringing': 1916, 'fix': 4819, '624': 6164, 'naturalite': 12096, 'wales': 6165, 'fin': 8807, 'fio': 11129, 'ceremenony': 20714, 'sovr': 20715, "yeo's": 20716, 'effects': 1788, 'sixteen': 13805, 'undeveloped': 8808, 'glutted': 13806, 'barton': 20717, 'froday': 20718, 'arrow': 10089, 'stabilises': 11002, 'allan': 6960, '374p': 20719, '393': 3891, '392': 4008, '391': 4206, '390': 3079, '397': 4550, '396': 6166, '395': 6423, '394': 4207, '399': 6961, '398': 4208, 'stabilised': 7595, 'smelters': 5114, 'oprah': 20720, 'orginially': 20721, "tvx's": 20722, 'ponomarev': 16278, 'enviroment': 20723, "reeves'": 20724, 'mason': 8363, 'encourage': 1670, 'adapt': 7596, 'abbott': 12776, 'stamping': 13808, 'colquiri': 20726, 'ambrit': 11003, 'strata': 8353, 'corrects': 4821, 'sandra': 11922, 'estimate': 859, 'universally': 20727, 'chlorine': 20728, 'competes': 16279, 'leiner': 10068, 'ministries': 8809, 'disturbed': 8810, 'competed': 13809, 'juergen': 8811, 'kfw': 13810, 'turben': 11004, 'reintroduced': 9384, 'maladies': 20729, 'chevron': 4101, 'lazere': 16280, 'antilles': 8812, 'dti': 11907, 'specially': 9070, 'bilzerian': 4678, 'bakelite': 13811, 'renovated': 20730, 'service': 568, 'payless': 16281, 'spiegler': 20731, 'needed': 831, 'wigglesworth': 16282, 'master': 6962, 'antonson': 13812, 'genesis': 20732, 'vismara': 13813, 'organically': 20734, "accords'": 20735, 'task': 5940, 'positively': 7974, 'feasibility': 3479, 'ahmed': 6963, "suralco's": 13814, 'awacs': 20736, 'idly': 16283, 'regulator': 20737, 'pseudorabies': 12097, 'staubli': 16284, 'nzi': 8813, 'feeling': 5115, '275': 3127, '6819': 20738, 'gorman': 16285, 'sustaining': 8354, 'spectrum': 9385, 'consenting': 20739, 'recapitalized': 12098, 'sailed': 11562, 'dozen': 7597, 'affairs': 1985, 'courier': 2253, 'kremlin': 8355, 'shipments': 895, "aquino's": 16286, 'committing': 10070, ...

# %%
# 뉴스 기사의 평균 단어 길이
plt.figure(figsize = (12,4))
len_sample = [len(x) for x in x_train]
plt.subplot(121);sns.histplot(x = len_sample)
plt.subplot(122);sns.countplot(x=y_train)
print('뉴스기사의 평균길이 : ', np.mean(len_sample))
# Out:
# 뉴스기사의 평균길이 :  145.5398574927633

# %%
# 데이터 전처리: 패딩
MAX_LEN = 128
x_train = preprocessing.sequence.pad_sequences(x_train, maxlen = MAX_LEN)
x_test = preprocessing.sequence.pad_sequences(x_test, maxlen = MAX_LEN)
print('훈련데이터 :', x_train.shape, y_train.shape)
print('테스트데이터 :', x_test.shape, y_test.shape)
# Out:
# 훈련데이터 : (8982, 128) (8982,)
# 테스트데이터 : (2246, 128) (2246,)

# %% [markdown]
# ### | 임베딩 매트릭스 제작
#
# ```
# ! gdown https://drive.google.com/u/0/uc?id=1ams5_zp8NrfmbxSzTDCglRpAvjFGi5JY&export=download
# ! unzip  /content/glove.6B.zip
# ```

# %%
! gdown https://drive.google.com/u/0/uc?id=1SskmaqNEYmXSADf3opvqoova08078lJV&export=download
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1SskmaqNEYmXSADf3opvqoova08078lJV
# To: /content/glove.6B.100d.txt
# 100% 347M/347M [00:04<00:00, 72.0MB/s]

# %%
! unzip  /content/glove.6B.zip

# %% [markdown]
# #### **단어-임베딩 딕셔너리**
#
# ```
# embeddings_index = {}
# f = open('glove.6B.100d.txt', encoding="utf8")
# for line in f:
#     values = line.split()
#     word = values[0]
#     coefs = np.asarray(values[1:], dtype='float32')
#     embeddings_index[word] = coefs
# f.close()
# ```

# %%
embeddings_index = {}
f = open('glove.6B.100d.txt', encoding="utf8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

# %% [markdown]
# #### **인덱싱-단어 딕셔너리**

# %%
word2index = tf.keras.datasets.reuters.get_word_index()
#print(index2word)
index2word = {}
for word, index in word2index.items():
  #print(word, index)
  index2word[index+3] = word
print(index2word)
# Out:
# {10999: 'mdbl', 16263: 'fawc', 12092: 'degussa', 8806: 'woods', 13799: 'hanging', 20675: 'localized', 20676: 'sation', 20678: 'chanthaburi', 11000: 'refunding', 8807: 'hermann', 20679: 'passsengers', 20680: 'stipulate', 8355: 'heublein', 20716: 'screaming', 16264: 'tcby', 188: 'four', 1645: 'grains', 20683: 'broiler', 12093: 'wooden', 1223: 'wednesday', 13800: 'highveld', 7596: 'duffour', 20684: '0053', 3917: 'elections', 2566: '270', 3554: '271', 5116: '272', 3555: '273', 3403: '274', 7978: 'rudman', 3404: '276', 3481: '277', 3635: '278', 4312: '279', 9384: 'dormancy', 7250: 'errors', 3089: 'deferred', 20686: 'sptnd', 8808: 'cooking', 20687: 'stratabit', 16265: 'designing', 20688: 'metalurgicos', 13801: 'databank', 20689: '300er', 20690: 'shocks', 7975: 'nawg', 20691: 'tnta', 20692: 'perforations', 2894: 'affiliates', 20693: '27p', 16266: 'ching', 598: 'china', 16267: 'wagyu', 3192: 'affiliated', 16268: 'chino', 16269: 'chinh', 20695: 'slickline', 13802: 'doldrums', 12095: 'kids', 3031: 'climbed', 6696: 'controversy', 20696: 'kidd', 12096: 'spotty', 12642: 'rebel', 9385: 'millimetres', 4010: 'golden', 5692: 'projection', 12097: 'stern', 7906: "hudson's", 10069: 'dna', 20698: 'dnc', 20699: 'hodler', 2397: 'lme', 20700: 'insolvancy', 13803: 'music', 1987: 'therefore', 11001: 'dns', 6962: 'distortions', 13804: 'thassos', 20701: 'populations', 8809: 'meteorologist', 46: 'loss', 9386: 'exco', 20816: 'adventist', 16270: 'murchison', 11002: 'locked', 13805: 'kampala', 20702: 'arndt', 1270: 'nakasone', 20703: 'steinweg', 3636: "india's", 3032: 'wang', 10070: 'wane', 13806: 'unjust', 13807: 'titanium', 853: 'want', 20704: 'pinto', 16271: "institutes'", 7976: 'absolute', 4680: 'travel', 6425: 'cutback', 16272: 'nazmi', 1861: 'modest', 16273: 'shopwell', 20705: 'sedi', 20706: 'adoped', 16274: 'tulis', 20707: '18th', 20708: "wmc's", 20709: 'menlo', 11003: 'reiners', 12098: 'farmlands', 20710: 'nonsensical', 20711: 'elisra', 2464: 'welcomed', 20712: 'peup', 16275: "holiday's", 20714: 'activating', 16276: 'avondale', 16277: 'interational', 20715: 'welcomes', 16278: 'fip', 11004: 'tailings', 4208: 'fit', 16279: 'lifeline', 1919: 'bringing', 4822: 'fix', 6167: '624', 12099: 'naturalite', 6168: 'wales', 8810: 'fin', 11132: 'fio', 20717: 'ceremenony', 20718: 'sovr', 20719: "yeo's", 1791: 'effects', 13808: 'sixteen', 8811: 'undeveloped', 13809: 'glutted', 20720: 'barton', 20721: 'froday', 10092: 'arrow', 11005: 'stabilises', 6963: 'allan', 20722: '374p', 3894: '393', 4011: '392', 4209: '391', 3082: '390', 4553: '397', 6169: '396', 6426: '395', 4210: '394', 6964: '399', 4211: '398', 7598: 'stabilised', 5117: 'smelters', 20723: 'oprah', 20724: 'orginially', 20725: "tvx's", 16281: 'ponomarev', 20726: 'enviroment', 20727: "reeves'", 8366: 'mason', 1673: 'encourage', 7599: 'adapt', 12779: 'abbott', 13811: 'stamping', 20729: 'colquiri', 11006: 'ambrit', 8356: 'strata', 4824: 'corrects', 11925: 'sandra', 862: 'estimate', 20730: 'universally', 20731: 'chlorine', 16282: 'competes', 10071: 'leiner', 8812: 'ministries', 8813: 'disturbed', 13812: 'competed', 8814: 'juergen', 13813: 'kfw', 11007: 'turben', 9387: 'reintroduced', 20732: 'maladies', 4104: 'chevron', 16283: 'lazere', 8815: 'antilles', 11910: 'dti', 9073: 'specially', 4681: 'bilzerian', 13814: 'bakelite', 20733: 'renovated', 571: 'service', 16284: 'payless', 20734: 'spiegler', 834: 'needed', 16285: 'wigglesworth', 6965: 'master', 13815: 'antonson', 20735: 'genesis', 13816: 'vismara', 20737: 'organically', 20738: "accords'", 5943: 'task', 7977: 'positively', 3482: 'feasibility', 6966: 'ahmed', 13817: "suralco's", 20739: 'awacs', 16286: 'idly', 20740: 'regulator', 12100: 'pseudorabies', 16287: 'staubli', 8816: 'nzi', 5118: 'feeling', 3130: '275', 20741: '6819', 16288: 'gorman', 8357: 'sustaining', 9388: 'spectrum', 20742: 'consenting', 12101: 'recapitalized', 11565: 'sailed', 7600: 'dozen', 1988: 'affairs', 2256: 'courier', 8358: 'kremlin', 898: 'shipments', 16289: "aquino's", 10073: 'committing', ...

# %%
for x in x_train[0]:
  if index2word.get(x) is not None:
    print(index2word[x]) # 1000개 단어 외에는 생략되기 때문에
# Out:
# said
# as
# a
# result
# of
# its
# december
# acquisition
# of
# co
# it
# expects
# earnings
# per
# share
# in
# 1987
# of
# 1
# 15
# to
# 1
# 30
# dlrs
# per
# share
# up
# from
# 70
# cts
# in
# 1986
# the
# company
# said
# pretax
# net
# should
# rise
# to
# nine
# to
# 10
# mln
# dlrs
# from
# six
# mln
# dlrs
# in
# 1986
# and
# revenues
# to
# 19
# to
# 22
# mln
# dlrs
# from
# 12
# 5
# mln
# dlrs
# it
# said
# cash
# per
# share
# this
# year
# should
# be
# 2
# 50
# to
# three
# dlrs
# reuter
# 3

# %% [markdown]
# #### **매트릭스 제작**

# %%
EMB_DIMS=100
embedding_matrix = np.zeros((MAX_FEATURES, EMB_DIMS))
print('임베딩 매트릭스 (W): ' , embedding_matrix.shape)
for i in range(1, MAX_FEATURES):
  idx=i+4
  word = index2word.get(idx)
  vec = embeddings_index.get(word)
  if vec is not None:
    embedding_matrix[i]=vec
    #print(i, idx, word, vec)
# Out:
# 임베딩 매트릭스 (W):  (1000, 100)

# %% [markdown]
# ### | 모델학습 1
#
# 이때까지 배운 레이어를 사용하여 모델을 구축하세요.
#
# ```
# Embedding()
# RNN()
# LSTM()
# GRU()
# GlobalAveragePooling1D()
# Dense()
# ```

# %%
EMB_DIMS = 100
x = layers.Input(shape = MAX_LEN)
y = layers.Embedding(MAX_FEATURES, EMB_DIMS)(x)
y = layers.GRU(64, return_sequences=True)(y)
y = layers.GRU(64, return_sequences=True)(y)
y = layers.GlobalAveragePooling1D()(y)
y = layers.Dense(46, activation = 'softmax')(y)

model = models.Model(x,y)
model.layers[1].set_weights([embedding_matrix])
model.compile(loss = 'sparse_categorical_crossentropy',
              optimizer = 'adam',
              metrics = ['acc'])

model.summary()
history = model.fit(x_train, y_train,
                    batch_size = 128,
                    epochs = 20,
                    validation_data = (x_test, y_test))

plot_lcurve([history], [''], ['dodgerblue'], x_itv = 5)
draw_cm(model, x_test, y_test)
# Out:
# Model: "model_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_27 (InputLayer)       [(None, 128)]             0
#
#  embedding_26 (Embedding)    (None, 128, 100)          100000
#
#  gru_29 (GRU)                (None, 128, 64)           31872
#
#  gru_30 (GRU)                (None, 128, 64)           24960
#
#  global_average_pooling1d_4   (None, 64)               0
#  (GlobalAveragePooling1D)
#
#  dense_22 (Dense)            (None, 46)                2990
#
# =================================================================
# Total params: 159,822
# Trainable params: 159,822
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 71/71 [==============================] - 5s 30ms/step - loss: 2.5397 - acc: 0.3820 - val_loss: 2.1171 - val_acc: 0.4439
# Epoch 2/20
# 71/71 [==============================] - 1s 17ms/step - loss: 2.0222 - acc: 0.4743 - val_loss: 1.9100 - val_acc: 0.5067
# Epoch 3/20
# 71/71 [==============================] - 1s 17ms/step - loss: 1.7800 - acc: 0.5519 - val_loss: 1.7262 - val_acc: 0.5735
# Epoch 4/20
# 71/71 [==============================] - 1s 16ms/step - loss: 1.6390 - acc: 0.6035 - val_loss: 1.6360 - val_acc: 0.6144
# Epoch 5/20
# 71/71 [==============================] - 1s 16ms/step - loss: 1.5159 - acc: 0.6261 - val_loss: 1.5539 - val_acc: 0.6247
# Epoch 6/20
# 71/71 [==============================] - 1s 18ms/step - loss: 1.3987 - acc: 0.6545 - val_loss: 1.4849 - val_acc: 0.6416
# Epoch 7/20
# 71/71 [==============================] - 1s 18ms/step - loss: 1.3022 - acc: 0.6772 - val_loss: 1.4216 - val_acc: 0.6545
# Epoch 8/20
# 71/71 [==============================] - 1s 16ms/step - loss: 1.2321 - acc: 0.6985 - val_loss: 1.3721 - val_acc: 0.6603
# Epoch 9/20
# 71/71 [==============================] - 1s 16ms/step - loss: 1.1679 - acc: 0.7124 - val_loss: 1.3524 - val_acc: 0.6696
# Epoch 10/20
# 71/71 [==============================] - 1s 17ms/step - loss: 1.1186 - acc: 0.7275 - val_loss: 1.3102 - val_acc: 0.6901
# Epoch 11/20
# 71/71 [==============================] - 1s 17ms/step - loss: 1.0574 - acc: 0.7457 - val_loss: 1.2865 - val_acc: 0.6888
# Epoch 12/20
# 71/71 [==============================] - 1s 17ms/step - loss: 1.0204 - acc: 0.7546 - val_loss: 1.2506 - val_acc: 0.7017
# Epoch 13/20
# 71/71 [==============================] - 1s 17ms/step - loss: 0.9776 - acc: 0.7636 - val_loss: 1.2557 - val_acc: 0.6995
# Epoch 14/20
# 71/71 [==============================] - 1s 17ms/step - loss: 0.9475 - acc: 0.7685 - val_loss: 1.2338 - val_acc: 0.7066
# Epoch 15/20
# 71/71 [==============================] - 1s 17ms/step - loss: 0.9055 - acc: 0.7797 - val_loss: 1.2246 - val_acc: 0.7110
# Epoch 16/20
# 71/71 [==============================] - 1s 17ms/step - loss: 0.8701 - acc: 0.7898 - val_loss: 1.2079 - val_acc: 0.7142
# Epoch 17/20
# 71/71 [==============================] - 1s 17ms/step - loss: 0.8411 - acc: 0.7966 - val_loss: 1.2201 - val_acc: 0.7093
# Epoch 18/20
# 71/71 [==============================] - 1s 17ms/step - loss: 0.8126 - acc: 0.8031 - val_loss: 1.2275 - val_acc: 0.7102
# Epoch 19/20
# 71/71 [==============================] - 1s 17ms/step - loss: 0.7845 - acc: 0.8094 - val_loss: 1.2025 - val_acc: 0.7195
# Epoch 20/20
# 71/71 [==============================] - 1s 16ms/step - loss: 0.7551 - acc: 0.8167 - val_loss: 1.1860 - val_acc: 0.7293

# %% [markdown]
# ### | 모델학습 2
#
# ![](https://www.researchgate.net/profile/Arvind-Mohan-3/publication/324769532/figure/fig2/AS:619510805561344@1524714294669/LSTM-and-BiLSTM-Architectures.png)

# %%
EMB_DIMS = 100
x = layers.Input(shape = MAX_LEN)
y = layers.Embedding(MAX_FEATURES, EMB_DIMS)(x)
y = layers.Bidirectional(layers.GRU(64, return_sequences=True))(y)
y = layers.Bidirectional(layers.GRU(64, return_sequences=True))(y)
y = layers.GRU(64, return_sequences=True)(y)
y = layers.GlobalAveragePooling1D()(y)
y = layers.Dense(46, activation = 'softmax')(y)

model = models.Model(x,y)
model.layers[1].set_weights([embedding_matrix])
model.compile(loss = 'sparse_categorical_crossentropy',
              optimizer = 'adam',
              metrics = ['acc'])

model.summary()
history = model.fit(x_train, y_train,
                    batch_size = 128,
                    epochs = 20,
                    validation_data = (x_test, y_test))

plot_lcurve([history], [''], ['dodgerblue'], x_itv = 5)
draw_cm(model, x_test, y_test)
# Out:
# Model: "model_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_28 (InputLayer)       [(None, 128)]             0
#
#  embedding_27 (Embedding)    (None, 128, 100)          100000
#
#  bidirectional (Bidirectiona  (None, 128, 128)         63744
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 128, 128)         74496
#  nal)
#
#  gru_33 (GRU)                (None, 128, 64)           37248
#
#  global_average_pooling1d_5   (None, 64)               0
#  (GlobalAveragePooling1D)
#
#  dense_23 (Dense)            (None, 46)                2990
#
# =================================================================
# Total params: 278,478
# Trainable params: 278,478
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 71/71 [==============================] - 11s 67ms/step - loss: 2.4108 - acc: 0.4005 - val_loss: 2.1025 - val_acc: 0.4933
# Epoch 2/20
# 71/71 [==============================] - 3s 42ms/step - loss: 1.9870 - acc: 0.5075 - val_loss: 1.9048 - val_acc: 0.5285
# Epoch 3/20
# 71/71 [==============================] - 3s 42ms/step - loss: 1.7760 - acc: 0.5561 - val_loss: 1.7614 - val_acc: 0.5623
# Epoch 4/20
# 71/71 [==============================] - 3s 42ms/step - loss: 1.5391 - acc: 0.6229 - val_loss: 1.5524 - val_acc: 0.6291
# Epoch 5/20
# 71/71 [==============================] - 3s 42ms/step - loss: 1.3924 - acc: 0.6620 - val_loss: 1.4373 - val_acc: 0.6398
# Epoch 6/20
# 71/71 [==============================] - 3s 42ms/step - loss: 1.2701 - acc: 0.6874 - val_loss: 1.3733 - val_acc: 0.6598
# Epoch 7/20
# 71/71 [==============================] - 3s 41ms/step - loss: 1.1899 - acc: 0.7017 - val_loss: 1.3203 - val_acc: 0.6728
# Epoch 8/20
# 71/71 [==============================] - 3s 42ms/step - loss: 1.1205 - acc: 0.7212 - val_loss: 1.2438 - val_acc: 0.6870
# Epoch 9/20
# 71/71 [==============================] - 3s 42ms/step - loss: 1.0559 - acc: 0.7411 - val_loss: 1.2303 - val_acc: 0.6852
# Epoch 10/20
# 71/71 [==============================] - 3s 42ms/step - loss: 0.9913 - acc: 0.7581 - val_loss: 1.1933 - val_acc: 0.6986
# Epoch 11/20
# 71/71 [==============================] - 3s 42ms/step - loss: 0.9362 - acc: 0.7700 - val_loss: 1.1491 - val_acc: 0.7106
# Epoch 12/20
# 71/71 [==============================] - 3s 42ms/step - loss: 0.8870 - acc: 0.7851 - val_loss: 1.1424 - val_acc: 0.7195
# Epoch 13/20
# 71/71 [==============================] - 3s 41ms/step - loss: 0.8370 - acc: 0.7978 - val_loss: 1.1233 - val_acc: 0.7226
# Epoch 14/20
# 71/71 [==============================] - 3s 42ms/step - loss: 0.7852 - acc: 0.8094 - val_loss: 1.1320 - val_acc: 0.7204
# Epoch 15/20
# 71/71 [==============================] - 3s 42ms/step - loss: 0.7488 - acc: 0.8196 - val_loss: 1.1006 - val_acc: 0.7351
# Epoch 16/20
# 71/71 [==============================] - 3s 42ms/step - loss: 0.7119 - acc: 0.8273 - val_loss: 1.1228 - val_acc: 0.7333
# Epoch 17/20
# 71/71 [==============================] - 3s 41ms/step - loss: 0.6679 - acc: 0.8385 - val_loss: 1.1153 - val_acc: 0.7346
# Epoch 18/20
# 71/71 [==============================] - 3s 42ms/step - loss: 0.6213 - acc: 0.8516 - val_loss: 1.1242 - val_acc: 0.7275
# Epoch 19/20
# 71/71 [==============================] - 3s 42ms/step - loss: 0.5934 - acc: 0.8592 - val_loss: 1.1405 - val_acc: 0.7275
# Epoch 20/20
# 71/71 [==============================] - 3s 42ms/step - loss: 0.5669 - acc: 0.8647 - val_loss: 1.1747 - val_acc: 0.7191

# %% [markdown]
# ## 스팀 리뷰 감성 분류
# ---
#
# https://wikidocs.net/94748
#
# ```
# # Colab에 Mecab 설치
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# %cd Mecab-ko-for-Google-Colab
# !bash install_mecab-ko_on_colab190912.sh
# ```

# %%
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# %cd Mecab-ko-for-Google-Colab
# !bash install_mecab-ko_on_colab190912.sh
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 115 (delta 11), reused 10 (delta 3), pack-reused 91
# Receiving objects: 100% (115/115), 1.27 MiB | 3.11 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# /content/Mecab-ko-for-Google-Colab
# Installing konlpy.....
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 719 kB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (453 kB)
#      |████████████████████████████████| 453 kB 62.8 MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (4.1.1)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.0 konlpy-0.6.0
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# Downloading mecab-0.996-ko-0.9.2.tar.gz.......
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2022-07-18 01:24:53--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::3403:4be7, 2406:da00:ff00::22cd:e0db, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNJRFMAEHA&Signature=kE%2BNWJymrHTmlL3uAD62Y3pKnPk%3D&x-amz-security-token=FwoGZXIvYXdzELv%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDOVOBZ0JedEE6rfr9iK%2BAd8DWEN8jko6zPmxpBTozitAqwBCR8lTJ6svNOqdiU0FtQ26yNu2ywbRkqQtFLJpXgut%2Bqehaut%2FKIKMrDSY5c2vuJ032QNBD7W48wmP2AMgQIFZIDJ6YbyOafxlW9TiFYjDwWU0Amm2n91asVN%2Fq91kFaFJRMzAup275PpD9A7v6M3bXqn9Uhs%2BxNzSlwreGR4o%2FfPn3EvzQZbrbl0JI164xH9wjuXATLEwNbh0WIeqV1uujYmNWvyDkwGk%2BD4o1%2BvSlgYyLfSDXcXPh2kTpVydx589gUUSZSk6jCJNWKno2ZhQPdFBDPb4jK18WDxSFWbNBA%3D%3D&Expires=1658109151 [following]
# --2022-07-18 01:24:54--  https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNJRFMAEHA&Signature=kE%2BNWJymrHTmlL3uAD62Y3pKnPk%3D&x-amz-security-token=FwoGZXIvYXdzELv%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDOVOBZ0JedEE6rfr9iK%2BAd8DWEN8jko6zPmxpBTozitAqwBCR8lTJ6svNOqdiU0FtQ26yNu2ywbRkqQtFLJpXgut%2Bqehaut%2FKIKMrDSY5c2vuJ032QNBD7W48wmP2AMgQIFZIDJ6YbyOafxlW9TiFYjDwWU0Amm2n91asVN%2Fq91kFaFJRMzAup275PpD9A7v6M3bXqn9Uhs%2BxNzSlwreGR4o%2FfPn3EvzQZbrbl0JI164xH9wjuXATLEwNbh0WIeqV1uujYmNWvyDkwGk%2BD4o1%2BvSlgYyLfSDXcXPh2kTpVydx589gUUSZSk6jCJNWKno2ZhQPdFBDPb4jK18WDxSFWbNBA%3D%3D&Expires=1658109151
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 52.216.110.195
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|52.216.110.195|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1414979 (1.3M) [application/x-tar]
# Saving to: ‘mecab-0.996-ko-0.9.2.tar.gz’
#
# mecab-0.996-ko-0.9. 100%[===================>]   1.35M  2.63MB/s    in 0.5s
#
# 2022-07-18 01:24:54 (2.63 MB/s) - ‘mecab-0.996-ko-0.9.2.tar.gz’ saved [1414979/1414979]
#
# Done
# Unpacking mecab-0.996-ko-0.9.2.tar.gz.......
# Done
# Change Directory to mecab-0.996-ko-0.9.2.......
# installing mecab-0.996-ko-0.9.2.tar.gz........
# configure
# make
# make check
# make install
# ldconfig
# Done
# Change Directory to /content
# Downloading mecab-ko-dic-2.1.1-20180720.tar.gz.......
# from https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# --2022-07-18 01:26:11--  https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::6b17:d1f5, 2406:da00:ff00::22cd:e0db, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNF4I23AZ4&Signature=CPNg55pMvBgAxXif6I%2BOWssASJw%3D&x-amz-security-token=FwoGZXIvYXdzELv%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDHdEgIaRgR%2FXJPis0iK%2BAQOClTe3zvnklnJZ62d5J4nsN32ng3AHAaR0f0RuvwYHNNCxX49Rav42Ka%2BPPQxdfQ48EeF1oPqYUgVcz8ZidITbpeH6ZIQU3ZEte%2B3X1R7ykWuhBIKBgDzfh8bXv0BivBYFG48wlzY2hQl0gUdHTscI2dDMMvfEkExniUmnkhA53me1wb1NBzMGblZ7rPznv3LErlJTvsI8cH%2BRQKJ7bz0J42YPrqI3xnvaWjl8jriOiAMiEM%2BZjY7phKrwJQ0o0%2BvSlgYyLfgFgGzajPj0XsW6GrTsS9SWSyEilAyaJMggnAgeSCH1AJaUm7TTvw76x0DLjQ%3D%3D&Expires=1658109147 [following]
# --2022-07-18 01:26:11--  https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNF4I23AZ4&Signature=CPNg55pMvBgAxXif6I%2BOWssASJw%3D&x-amz-security-token=FwoGZXIvYXdzELv%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDHdEgIaRgR%2FXJPis0iK%2BAQOClTe3zvnklnJZ62d5J4nsN32ng3AHAaR0f0RuvwYHNNCxX49Rav42Ka%2BPPQxdfQ48EeF1oPqYUgVcz8ZidITbpeH6ZIQU3ZEte%2B3X1R7ykWuhBIKBgDzfh8bXv0BivBYFG48wlzY2hQl0gUdHTscI2dDMMvfEkExniUmnkhA53me1wb1NBzMGblZ7rPznv3LErlJTvsI8cH%2BRQKJ7bz0J42YPrqI3xnvaWjl8jriOiAMiEM%2BZjY7phKrwJQ0o0%2BvSlgYyLfgFgGzajPj0XsW6GrTsS9SWSyEilAyaJMggnAgeSCH1AJaUm7TTvw76x0DLjQ%3D%3D&Expires=1658109147
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 52.216.246.100
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|52.216.246.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49775061 (47M) [application/x-tar]
# Saving to: ‘mecab-ko-dic-2.1.1-20180720.tar.gz’
#
# mecab-ko-dic-2.1.1- 100%[===================>]  47.47M  24.8MB/s    in 1.9s
#
# 2022-07-18 01:26:14 (24.8 MB/s) - ‘mecab-ko-dic-2.1.1-20180720.tar.gz’ saved [49775061/49775061]
#
# Done
# Unpacking  mecab-ko-dic-2.1.1-20180720.tar.gz.......
# Done
# Change Directory to mecab-ko-dic-2.1.1-20180720
# Done
# installing........
# configure
# make
# make install
# apt-get update
# apt-get upgrade
# apt install curl
# apt install git
# bash <(curl -s https://raw.githubusercontent.com/konlpy/konlpy/master/scripts/mecab.sh)
# Done
# Successfully Installed
# Now you can use Mecab
# from konlpy.tag import Mecab
# mecab = Mecab()
# 사용자 사전 추가 방법 : https://bit.ly/3k0ZH53
# NameError: name 'Tagger' is not defined 오류 발생 시 런타임을 재실행 해주세요
# 블로그에 해결 방법을 남겨주신 tana님 감사합니다.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import urllib.request
from collections import Counter
from konlpy.tag import Mecab
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/bab2min/corpus/master/sentiment/steam.txt", filename="steam.txt")
# Out:
# ('steam.txt', <http.client.HTTPMessage at 0x7f9fe38fcdd0>)

# %%
total_data = pd.read_table('steam.txt', names=['label', 'reviews'])
print('전체 리뷰 개수 :',len(total_data)) # 전체 리뷰 개수 출력
# Out:
# 전체 리뷰 개수 : 100000

# %%
total_data[:10]
# Out:
#    label                                            reviews
# 0      0                                          노래가 너무 적음
# 1      0                    돌겠네 진짜. 황숙아, 어크 공장 그만 돌려라. 죽는다.
# 2      1                   막노동 체험판 막노동 하는사람인데 장비를 내가 사야돼 뭐지
# 3      1               차악!차악!!차악!!! 정말 이래서 왕국을 되찾을 수 있는거야??
# 4      1                시간 때우기에 좋음.. 도전과제는 50시간이면 다 깰 수 있어요
# 5      1              역시 재미있네요 전작에서 할수 없었던 자유로운 덱 빌딩도 좋네요^^
# 6      1                                           재미있었습니다.
# 7      1                                   은근 쉽지만 은근 어려운 게임
# 8      0  베ㅈ스다 이 개^ㅐ끼들아. 시작할 때 체스판 돌아가는거 5분동안 3번 봤더나 ㅈㄴ ...
# 9      1                             1시간 40분동안 스트레스 다 풀림 ㄹㅇ

# %%
total_data['reviews'].nunique(), total_data['label'].nunique()
# Out:
# (99892, 2)

# %%
total_data.drop_duplicates(subset=['reviews'], inplace=True) # reviews 열에서 중복인 내용이 있다면 중복 제거
print('총 샘플의 수 :',len(total_data))
# Out:
# 총 샘플의 수 : 99892

# %%
total_data.isnull().sum() # 결측치 확인 결과 없음
# Out:
# label      0
# reviews    0
# dtype: int64

# %%
# 훈련데이터 테스트 데이터 분리
train_data, test_data = train_test_split(total_data, test_size = 0.25, random_state = 42)
print('훈련용 리뷰의 개수 :', len(train_data))
print('테스트용 리뷰의 개수 :', len(test_data))
# Out:
# 훈련용 리뷰의 개수 : 74919
# 테스트용 리뷰의 개수 : 24973

# %%
train_data['label'].value_counts().plot(kind = 'bar')

# %%
# 한글과 공백을 제외하고 모두 제거
train_data['reviews'] = train_data['reviews'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
train_data['reviews'].replace('', np.nan, inplace=True)
print(train_data.isnull().sum())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
# label      0
# reviews    0
# dtype: int64

# %%
# train 셋과 동일한 전처리 시행
test_data.drop_duplicates(subset = ['reviews'], inplace=True) # 중복 제거
test_data['reviews'] = test_data['reviews'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규 표현식 수행
test_data['reviews'].replace('', np.nan, inplace=True) # 공백은 Null 값으로 변경
test_data = test_data.dropna(how='any') # Null 값 제거
print('전처리 후 테스트용 샘플의 개수 :',len(test_data))
# Out:
# 전처리 후 테스트용 샘플의 개수 : 24973
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
# 불용어 정의
stopwords = ['도', '는', '다', '의', '가', '이', '은', '한', '에', '하', '고', '을', '를', '인', '듯', '과', '와', '네', '들', '듯', '지', '임', '게', '만', '게임', '겜', '되', '음', '면']

# %%
# 형태소 분석기로 train, test 셋 토큰화 진행
mecab = Mecab() 

train_data['tokenized'] = train_data['reviews'].apply(mecab.morphs)
train_data['tokenized'] = train_data['tokenized'].apply(lambda x: [item for item in x if item not in stopwords])
test_data['tokenized'] = test_data['reviews'].apply(mecab.morphs)
test_data['tokenized'] = test_data['tokenized'].apply(lambda x: [item for item in x if item not in stopwords])

# %%
# 긍정적 단어와 부정적 단어 그룹화
negative_words = np.hstack(train_data[train_data.label == 0]['tokenized'].values)
positive_words = np.hstack(train_data[train_data.label == 1]['tokenized'].values)

# %%
# 부정적인 단어에서 가장 빈도수가 많은 20개
negative_word_count = Counter(negative_words)
print(negative_word_count.most_common(20))
# Out:
# [('안', 8129), ('없', 7141), ('는데', 5786), ('있', 5692), ('같', 4247), ('로', 4083), ('할', 3920), ('거', 3902), ('나', 3805), ('해', 3653), ('너무', 3522), ('으로', 3351), ('기', 3348), ('했', 3265), ('어', 3143), ('보', 2987), ('습니다', 2962), ('것', 2935), ('지만', 2911), ('좋', 2899)]

# %%
# 긍정적인 단어에서 가장 빈도수가 많은 20개
positive_word_count = Counter(positive_words)
print(positive_word_count.most_common(20))
# Out:
# [('있', 9987), ('좋', 6542), ('습니다', 5179), ('재밌', 4997), ('할', 4838), ('지만', 4809), ('해', 4354), ('없', 4145), ('보', 3907), ('으로', 3900), ('로', 3879), ('수', 3835), ('는데', 3825), ('기', 3592), ('안', 3368), ('것', 3362), ('같', 3356), ('네요', 3189), ('어', 3112), ('나', 3055)]

# %%
# 긍정과 부정적인 리뷰의 평균 길이
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(10,5))
text_len = train_data[train_data['label']==1]['tokenized'].map(lambda x: len(x))
ax1.hist(text_len, color='red')
ax1.set_title('Positive Reviews')
ax1.set_xlabel('length of samples')
ax1.set_ylabel('number of samples')
print('긍정 리뷰의 평균 길이 :', np.mean(text_len))

text_len = train_data[train_data['label']==0]['tokenized'].map(lambda x: len(x))
ax2.hist(text_len, color='blue')
ax2.set_title('Negative Reviews')
fig.suptitle('Words in texts')
ax2.set_xlabel('length of samples')
ax2.set_ylabel('number of samples')
print('부정 리뷰의 평균 길이 :', np.mean(text_len))
plt.show()
# Out:
# 긍정 리뷰의 평균 길이 : 14.948459100231734
# 부정 리뷰의 평균 길이 : 15.284193065068493

# %%
X_train = train_data['tokenized'].values
y_train = train_data['label'].values
X_test= test_data['tokenized'].values
y_test = test_data['label'].values

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# %%
tokenizer.word_index
# Out:
# {'있': 1,
#  '안': 2,
#  '없': 3,
#  '는데': 4,
#  '좋': 5,
#  '할': 6,
#  '습니다': 7,
#  '해': 8,
#  '로': 9,
#  '지만': 10,
#  '같': 11,
#  '으로': 12,
#  '기': 13,
#  '보': 14,
#  '나': 15,
#  '거': 16,
#  '재밌': 17,
#  '것': 18,
#  '했': 19,
#  '어': 20,
#  '수': 21,
#  '네요': 22,
#  '너무': 23,
#  '아': 24,
#  '않': 25,
#  '적': 26,
#  '플레이': 27,
#  '좀': 28,
#  '었': 29,
#  '겠': 30,
#  '시간': 31,
#  '에서': 32,
#  '사': 33,
#  '때': 34,
#  '주': 35,
#  '함': 36,
#  '입니다': 37,
#  '재미': 38,
#  '사람': 39,
#  '아니': 40,
#  '개': 41,
#  '더': 42,
#  '추천': 43,
#  '내': 44,
#  '서': 45,
#  '잘': 46,
#  '스토리': 47,
#  '재미있': 48,
#  '라': 49,
#  '그냥': 50,
#  '합니다': 51,
#  '생각': 52,
#  '왜': 53,
#  '말': 54,
#  '았': 55,
#  '못': 56,
#  '시': 57,
#  '보다': 58,
#  '해서': 59,
#  '많': 60,
#  '잼': 61,
#  '으면': 62,
#  '한글': 63,
#  '갓': 64,
#  '어서': 65,
#  '싶': 66,
#  '진짜': 67,
#  '분': 68,
#  '정말': 69,
#  '그': 70,
#  '모르': 71,
#  '이거': 72,
#  '돈': 73,
#  '버그': 74,
#  '만들': 75,
#  '그래픽': 76,
#  '던': 77,
#  '번': 78,
#  '세요': 79,
#  '정도': 80,
#  '면서': 81,
#  '감': 82,
#  '뭐': 83,
#  '화': 84,
#  '니': 85,
#  '까지': 86,
#  '원': 87,
#  '중': 88,
#  '다가': 89,
#  '어요': 90,
#  '긴': 91,
#  '야': 92,
#  '멀티': 93,
#  '라고': 94,
#  '친구': 95,
#  '건': 96,
#  '냐': 97,
#  '데': 98,
#  'ㅋㅋㅋ': 99,
#  '알': 100,
#  '성': 101,
#  '조작': 102,
#  '느낌': 103,
#  '인데': 104,
#  '환불': 105,
#  '처음': 106,
#  '하나': 107,
#  '이게': 108,
#  '샀': 109,
#  '퍼즐': 110,
#  '아서': 111,
#  'ㅋㅋ': 112,
#  '구매': 113,
#  '은데': 114,
#  '받': 115,
#  '랑': 116,
#  '걸': 117,
#  '됨': 118,
#  '많이': 119,
#  '패치': 120,
#  '다시': 121,
#  '길': 122,
#  '노': 123,
#  '다른': 124,
#  '엔딩': 125,
#  '이런': 126,
#  '나오': 127,
#  '실행': 128,
#  '다고': 129,
#  '때문': 130,
#  '해야': 131,
#  '봤': 132,
#  '시작': 133,
#  '서버': 134,
#  '해도': 135,
#  '그리고': 136,
#  '자': 137,
#  '점': 138,
#  '이상': 139,
#  '라는': 140,
#  '괜찮': 141,
#  '다면': 142,
#  '는지': 143,
#  '난이도': 144,
#  '어렵': 145,
#  '무료': 146,
#  '전': 147,
#  '계속': 148,
#  '근데': 149,
#  '다는': 150,
#  '도전': 151,
#  '한다': 152,
#  '망': 153,
#  '이나': 154,
#  '같이': 155,
#  '요': 156,
#  '줄': 157,
#  '별로': 158,
#  '저': 159,
#  '편': 160,
#  '맞': 161,
#  '자체': 162,
#  '진행': 163,
#  '일': 164,
#  '년': 165,
#  '부터': 166,
#  '모드': 167,
#  '매우': 168,
#  '된': 169,
#  '마': 170,
#  '엔': 171,
#  '아직': 172,
#  '지금': 173,
#  '존나': 174,
#  '찾': 175,
#  '시리즈': 176,
#  '스팀': 177,
#  '죽': 178,
#  '가격': 179,
#  '조금': 180,
#  '비': 181,
#  '과제': 182,
#  '먹': 183,
#  '세일': 184,
#  '가능': 185,
#  '캐릭터': 186,
#  '오': 187,
#  '그래도': 188,
#  '시발': 189,
#  '제': 190,
#  '지원': 191,
#  '맵': 192,
#  '에게': 193,
#  '필요': 194,
#  '짧': 195,
#  '지루': 196,
#  '한데': 197,
#  '살': 198,
#  '유저': 199,
#  '재미없': 200,
#  '이건': 201,
#  '라면': 202,
#  '아요': 203,
#  '기대': 204,
#  'ㅈ': 205,
#  '타임': 206,
#  '깨': 207,
#  '문제': 208,
#  '며': 209,
#  '몇': 210,
#  '마세요': 211,
#  '니까': 212,
#  '키': 213,
#  '잡': 214,
#  '업데이트': 215,
#  '볼': 216,
#  'ㅠㅠ': 217,
#  '쓰': 218,
#  '치': 219,
#  '난': 220,
#  '쓰레기': 221,
#  '어떻게': 222,
#  '재': 223,
#  '할인': 224,
#  '이랑': 225,
#  '화면': 226,
#  '진': 227,
#  '최고': 228,
#  '비추': 229,
#  '전투': 230,
#  '였': 231,
#  '좆': 232,
#  '남': 233,
#  '만든': 234,
#  '끝': 235,
#  '평가': 236,
#  '판': 237,
#  '용': 238,
#  '인지': 239,
#  '드': 240,
#  '가지': 241,
#  '두': 242,
#  '본': 243,
#  '영어': 244,
#  '못하': 245,
#  '하지만': 246,
#  '건지': 247,
#  '즐기': 248,
#  '불편': 249,
#  '꼭': 250,
#  '무슨': 251,
#  '높': 252,
#  '시스템': 253,
#  '단점': 254,
#  '죠': 255,
#  '될': 256,
#  '액션': 257,
#  '요소': 258,
#  '부족': 259,
#  '병신': 260,
#  '컨텐츠': 261,
#  '대': 262,
#  '놓': 263,
#  '오류': 264,
#  '개인': 265,
#  '됩니다': 266,
#  '전작': 267,
#  '쉽': 268,
#  '없이': 269,
#  '뭔가': 270,
#  '아쉽': 271,
#  '일단': 272,
#  '다만': 273,
#  '후': 274,
#  '넘': 275,
#  '반복': 276,
#  '플': 277,
#  '려고': 278,
#  '부분': 279,
#  '여': 280,
#  '크': 281,
#  '이걸': 282,
#  '한국어': 283,
#  '꿀': 284,
#  '불': 285,
#  '솔직히': 286,
#  '모든': 287,
#  '맛': 288,
#  '그런': 289,
#  '마다': 290,
#  '빡': 291,
#  '렉': 292,
#  '된다': 293,
#  '보이': 294,
#  '설정': 295,
#  '처럼': 296,
#  '팅': 297,
#  '아주': 298,
#  '나름': 299,
#  '새끼': 300,
#  '배': 301,
#  '딱': 302,
#  '뜨': 303,
#  '스': 304,
#  '뿐': 305,
#  '명작': 306,
#  '짜증': 307,
#  '초반': 308,
#  '힘들': 309,
#  '이렇게': 310,
#  '또': 311,
#  '핵': 312,
#  '바로': 313,
#  'ㄷ': 314,
#  '즐길': 315,
#  '그렇': 316,
#  '산': 317,
#  '꽤': 318,
#  '추가': 319,
#  '버리': 320,
#  '더니': 321,
#  '패드': 322,
#  '분위기': 323,
#  '혼자': 324,
#  '버전': 325,
#  '싫': 326,
#  '타격': 327,
#  '빼': 328,
#  '옵': 329,
#  '가장': 330,
#  '밋': 331,
#  '명': 332,
#  '작품': 333,
#  '이유': 334,
#  '제발': 335,
#  '엄청': 336,
#  '작': 337,
#  '애': 338,
#  '절대': 339,
#  '수준': 340,
#  '참': 341,
#  '타': 342,
#  'ㄹ': 343,
#  '노가다': 344,
#  '추억': 345,
#  '신': 346,
#  '프레임': 347,
#  'ㅎㅎ': 348,
#  '역시': 349,
#  '오래': 350,
#  '걍': 351,
#  '등': 352,
#  '카드': 353,
#  '아닌': 354,
#  '취향': 355,
#  '총': 356,
#  '이제': 357,
#  '놈': 358,
#  '나쁘': 359,
#  '제대로': 360,
#  '발': 361,
#  '질': 362,
#  '마음': 363,
#  '키보드': 364,
#  '라서': 365,
#  '한테': 366,
#  '한국': 367,
#  '빨리': 368,
#  '손': 369,
#  '머리': 370,
#  '기분': 371,
#  '들어가': 372,
#  'ㅅ': 373,
#  '어도': 374,
#  '장점': 375,
#  '씩': 376,
#  '단순': 377,
#  '눈': 378,
#  '차라리': 379,
#  '거나': 380,
#  '이해': 381,
#  '세이브': 382,
#  '보스': 383,
#  '는다': 384,
#  '천': 385,
#  '물': 386,
#  '무기': 387,
#  '음악': 388,
#  '실': 389,
#  '라도': 390,
#  '만큼': 391,
#  '쳐': 392,
#  '아깝': 393,
#  '으니': 394,
#  '으나': 395,
#  '다양': 396,
#  '씹': 397,
#  '풀': 398,
#  '마우스': 399,
#  '자꾸': 400,
#  '옛날': 401,
#  '팔': 402,
#  '어디': 403,
#  '컴퓨터': 404,
#  '당신': 405,
#  '님': 406,
#  '저장': 407,
#  '밸런스': 408,
#  '인생': 409,
#  '동안': 410,
#  'ㅇ': 411,
#  '공포': 412,
#  '최적화': 413,
#  '로딩': 414,
#  '인가': 415,
#  '상당히': 416,
#  '다음': 417,
#  '아님': 418,
#  '만드': 419,
#  '짐': 420,
#  '핑': 421,
#  '답': 422,
#  '해결': 423,
#  '차': 424,
#  '배경': 425,
#  '뒤': 426,
#  '약간': 427,
#  '컴': 428,
#  '방식': 429,
#  '후회': 430,
#  '비해': 431,
#  '미션': 432,
#  'ㄴ': 433,
#  '러': 434,
#  '구입': 435,
#  '삭제': 436,
#  '설명': 437,
#  '빨': 438,
#  '거의': 439,
#  '이후': 440,
#  '돼': 441,
#  '간단': 442,
#  '어야': 443,
#  '싱글': 444,
#  '매칭': 445,
#  '온라인': 446,
#  '사양': 447,
#  '튕기': 448,
#  '컨트롤': 449,
#  '해요': 450,
#  '중간': 451,
#  'ㅡㅡ': 452,
#  '사용': 453,
#  '느끼': 454,
#  '이것': 455,
#  '방법': 456,
#  '셈': 457,
#  '소리': 458,
#  '여러': 459,
#  '주인공': 460,
#  '글': 461,
#  '출시': 462,
#  '비슷': 463,
#  '큰': 464,
#  '나요': 465,
#  '좋아하': 466,
#  '굉장히': 467,
#  '걸리': 468,
#  '레벨': 469,
#  '마지막': 470,
#  '날': 471,
#  '어려운': 472,
#  '바': 473,
#  '어느': 474,
#  '멀미': 475,
#  '스테이지': 476,
#  '업': 477,
#  '워': 478,
#  '넣': 479,
#  '사세요': 480,
#  '해라': 481,
#  '번역': 482,
#  '드립니다': 483,
#  '만족': 484,
#  '그래서': 485,
#  '막': 486,
#  '방': 487,
#  '나왔': 488,
#  '가끔': 489,
#  '실망': 490,
#  '뭘': 491,
#  '갑자기': 492,
#  '쯤': 493,
#  '클리어': 494,
#  '개꿀': 495,
#  '미친': 496,
#  '좆같': 497,
#  '깔': 498,
#  '튜토리얼': 499,
#  '속': 500,
#  '제일': 501,
#  '코': 502,
#  '팬': 503,
#  '물론': 504,
#  '전혀': 505,
#  '든': 506,
#  '다운': 507,
#  '싸': 508,
#  '사실': 509,
#  '설치': 510,
#  '접': 511,
#  '밖에': 512,
#  '한다면': 513,
#  '리': 514,
#  '자신': 515,
#  '얻': 516,
#  '연출': 517,
#  '뭔': 518,
#  '아무': 519,
#  '째': 520,
#  '씨': 521,
#  '집': 522,
#  '운': 523,
#  '잇': 524,
#  '란': 525,
#  '앞': 526,
#  '기본': 527,
#  '아쉬운': 528,
#  '별': 529,
#  '그림': 530,
#  '충분히': 531,
#  '언제': 532,
#  '급': 533,
#  '현실': 534,
#  '꺼': 535,
#  '아이템': 536,
#  '류': 537,
#  '훌륭': 538,
#  '창': 539,
#  '켜': 540,
#  '어려움': 541,
#  '쏘': 542,
#  '다니': 543,
#  'ㄱ': 544,
#  '정신': 545,
#  'ㅋ': 546,
#  '내용': 547,
#  '밖': 548,
#  '영화': 549,
#  '나가': 550,
#  '클릭': 551,
#  '그렇게': 552,
#  '그러': 553,
#  '턴': 554,
#  '힐링': 555,
#  '선택': 556,
#  '무엇': 557,
#  '듬': 558,
#  '답답': 559,
#  '완전': 560,
#  '누르': 561,
#  '에요': 562,
#  '전부': 563,
#  '모두': 564,
#  '너': 565,
#  '얼리': 566,
#  '미': 567,
#  '최악': 568,
#  '클': 569,
#  '달': 570,
#  '트': 571,
#  '모바일': 572,
#  '이야기': 573,
#  '흥미': 574,
#  '예전': 575,
#  '귀엽': 576,
#  '기능': 577,
#  '따': 578,
#  '겟': 579,
#  '맘': 580,
#  '짓': 581,
#  '줬': 582,
#  '그런지': 583,
#  'ㅠ': 584,
#  '캐': 585,
#  '영상': 586,
#  'ㅂ': 587,
#  '특히': 588,
#  '팀': 589,
#  '나중': 590,
#  '낮': 591,
#  '우리': 592,
#  '플레이어': 593,
#  '훨씬': 594,
#  '개발': 595,
#  '함께': 596,
#  '몰입': 597,
#  '질리': 598,
#  '봐야': 599,
#  '죽이': 600,
#  '인물': 601,
#  '공략': 602,
#  '됐': 603,
#  '그대로': 604,
#  '결국': 605,
#  '암': 606,
#  '박': 607,
#  '딱히': 608,
#  '완벽': 609,
#  '전체': 610,
#  '가볍': 611,
#  '사운드': 612,
#  '찍': 613,
#  '거지': 614,
#  '윈도우': 615,
#  '돌': 616,
#  '퀄리티': 617,
#  '잠깐': 618,
#  '월드': 619,
#  '퀘스트': 620,
#  '시키': 621,
#  '구': 622,
#  '힘': 623,
#  '파': 624,
#  '겁니다': 625,
#  '가치': 626,
#  '나온': 627,
#  '무한': 628,
#  '속도': 629,
#  '회차': 630,
#  '전략': 631,
#  '적당': 632,
#  '그런데': 633,
#  '소울': 634,
#  '단': 635,
#  '케': 636,
#  '매력': 637,
#  '똑같': 638,
#  '려면': 639,
#  '금방': 640,
#  '강추': 641,
#  '길래': 642,
#  '버렸': 643,
#  '그것': 644,
#  '경우': 645,
#  '스트레스': 646,
#  '최적': 647,
#  '위': 648,
#  '보단': 649,
#  '심하': 650,
#  '엔진': 651,
#  '스럽': 652,
#  '초': 653,
#  '알려': 654,
#  '여기': 655,
#  '덕': 656,
#  '탐': 657,
#  '대한': 658,
#  '까': 659,
#  '무': 660,
#  'ㅎ': 661,
#  '무조건': 662,
#  '언어': 663,
#  '값': 664,
#  '을까': 665,
#  '아무리': 666,
#  '그저': 667,
#  '텐데': 668,
#  '새로운': 669,
#  '우주': 670,
#  '디자인': 671,
#  '도트': 672,
#  '중독': 673,
#  '느낄': 674,
#  '머': 675,
#  '위해': 676,
#  '세': 677,
#  '개발자': 678,
#  '이딴': 679,
#  '순간': 680,
#  '곳': 681,
#  '믿': 682,
#  '김': 683,
#  '하고': 684,
#  '보여': 685,
#  '인터페이스': 686,
#  '갈수록': 687,
#  '장르': 688,
#  '무섭': 689,
#  '존': 690,
#  '그게': 691,
#  '극': 692,
#  '정가': 693,
#  '대체': 694,
#  '둘': 695,
#  '볼륨': 696,
#  '욕': 697,
#  '오브': 698,
#  '나올': 699,
#  '이번': 700,
#  '그거': 701,
#  '다크': 702,
#  '기억': 703,
#  '파일': 704,
#  '돌아가': 705,
#  '삼': 706,
#  '낫': 707,
#  '신선': 708,
#  '브금': 709,
#  '쉬': 710,
#  '모션': 711,
#  '심심': 712,
#  '간': 713,
#  '상': 714,
#  '첫': 715,
#  '현질': 716,
#  '다르': 717,
#  '빠': 718,
#  '참신': 719,
#  '오랜만': 720,
#  '아야': 721,
#  '대로': 722,
#  '여러분': 723,
#  '됬': 724,
#  '생존': 725,
#  '그러나': 726,
#  '인디': 727,
#  '짜리': 728,
#  '노래': 729,
#  '복잡': 730,
#  '겁나': 731,
#  '떨어지': 732,
#  '버튼': 733,
#  '얼마나': 734,
#  '오픈': 735,
#  '마스터': 736,
#  '점프': 737,
#  '고전': 738,
#  '식': 739,
#  '상태': 740,
#  '못함': 741,
#  '거기': 742,
#  '개선': 743,
#  '고인': 744,
#  '쉬운': 745,
#  '롭': 746,
#  '스킬': 747,
#  '몰': 748,
#  '발전': 749,
#  '의미': 750,
#  '귀찮': 751,
#  '공격': 752,
#  '관리': 753,
#  '달리': 754,
#  '세계': 755,
#  '접속': 756,
#  '버린': 757,
#  '킬링': 758,
#  '으며': 759,
#  '레이싱': 760,
#  '인간': 761,
#  '너무나': 762,
#  '정식': 763,
#  '형': 764,
#  '외': 765,
#  '아도': 766,
#  '시점': 767,
#  '하루': 768,
#  '친절': 769,
#  '감동': 770,
#  '문명': 771,
#  '후속작': 772,
#  '포': 773,
#  '분명': 774,
#  '엑': 775,
#  '임은': 776,
#  '익숙': 777,
#  '제작자': 778,
#  '콜': 779,
#  '버': 780,
#  '준': 781,
#  '중요': 782,
#  '군요': 783,
#  '자주': 784,
#  '피': 785,
#  '후반': 786,
#  '법': 787,
#  '반': 788,
#  '아무것': 789,
#  '구요': 790,
#  '조차': 791,
#  '슈팅': 792,
#  '고쳐': 793,
#  '쓸': 794,
#  '자마자': 795,
#  '어떤': 796,
#  '이미': 797,
#  '참고': 798,
#  '이동': 799,
#  '입': 800,
#  '확실히': 801,
#  '흠': 802,
#  '귀여운': 803,
#  '불친절': 804,
#  '자기': 805,
#  '포기': 806,
#  '했었': 807,
#  '굿': 808,
#  '잘못': 809,
#  '봐': 810,
#  '위한': 811,
#  '디펜스': 812,
#  '구성': 813,
#  '존재': 814,
#  '진심': 815,
#  '졌': 816,
#  '이름': 817,
#  '던가': 818,
#  '현재': 819,
#  '뭔지': 820,
#  '줘': 821,
#  '약': 822,
#  '심각': 823,
#  '감사': 824,
#  '한국인': 825,
#  '수정': 826,
#  '기준': 827,
#  '초기': 828,
#  '넘어가': 829,
#  '비싸': 830,
#  '움직이': 831,
#  '지나': 832,
#  '차이': 833,
#  '바꾸': 834,
#  '장난': 835,
#  '셨': 836,
#  '리듬': 837,
#  '올': 838,
#  '그나마': 839,
#  '느껴': 840,
#  '회사': 841,
#  '잖아': 842,
#  '햇': 843,
#  '갔': 844,
#  '깰': 845,
#  '종료': 846,
#  '맨': 847,
#  '리어': 848,
#  '아쉬움': 849,
#  '읽': 850,
#  '로그라이크': 851,
#  '랍': 852,
#  '얼마': 853,
#  '굳이': 854,
#  '더라': 855,
#  '즐겁': 856,
#  '섭': 857,
#  '갈': 858,
#  '직접': 859,
#  '끄': 860,
#  '폰': 861,
#  '운영': 862,
#  '따라': 863,
#  '캠페인': 864,
#  '한번': 865,
#  'ㅇㅇ': 866,
#  '그럼': 867,
#  '삿': 868,
#  '부': 869,
#  '파밍': 870,
#  '라이프': 871,
#  '봄': 872,
#  '도저히': 873,
#  '점점': 874,
#  '왔': 875,
#  '에겐': 876,
#  '도대체': 877,
#  '힘든': 878,
#  '팩': 879,
#  '적응': 880,
#  '스타일': 881,
#  '장벽': 882,
#  '튕김': 883,
#  '초보': 884,
#  'ㅣ': 885,
#  '한다고': 886,
#  '든다': 887,
#  '대전': 888,
#  '에러': 889,
#  '짱': 890,
#  '프로그램': 891,
#  '그리': 892,
#  '건가': 893,
#  '종류': 894,
#  '아예': 895,
#  '아닙니다': 896,
#  '건데': 897,
#  '몹': 898,
#  '비교': 899,
#  '기존': 900,
#  '시대': 901,
#  '니깐': 902,
#  '사고': 903,
#  '도록': 904,
#  '디': 905,
#  '점수': 906,
#  '현상': 907,
#  '누가': 908,
#  '한다는': 909,
#  '맞추': 910,
#  '템': 911,
#  '으면서': 912,
#  '열': 913,
#  '터': 914,
#  '에선': 915,
#  '입문': 916,
#  '려': 917,
#  '엄청난': 918,
#  '나와서': 919,
#  '만나': 920,
#  '적당히': 921,
#  '거리': 922,
#  '세상': 923,
#  '조': 924,
#  '벌': 925,
#  '하프': 926,
#  '써': 927,
#  '월': 928,
#  '신경': 929,
#  '사기': 930,
#  '요즘': 931,
#  '여전히': 932,
#  '와서': 933,
#  '갑니다': 934,
#  '시뮬레이터': 935,
#  '나옴': 936,
#  '시뮬레이션': 937,
#  '자동': 938,
#  '그럭저럭': 939,
#  '따로': 940,
#  '더럽': 941,
#  '무난': 942,
#  '못한': 943,
#  '달성': 944,
#  '못했': 945,
#  '떄': 946,
#  '런': 947,
#  '레': 948,
#  '뽕': 949,
#  '이러': 950,
#  '마시': 951,
#  '먼저': 952,
#  '곤': 953,
#  '듣': 954,
#  '컨셉': 955,
#  '스러운': 956,
#  '돌리': 957,
#  '메인': 958,
#  '사면': 959,
#  '킹': 960,
#  'ㅜㅜ': 961,
#  '고민': 962,
#  '상황': 963,
#  '한판': 964,
#  '공짜': 965,
#  '굳': 966,
#  '어쩌': 967,
#  '옵션': 968,
#  '끼리': 969,
#  '플랫': 970,
#  '원래': 971,
#  '으신': 972,
#  '기다리': 973,
#  '이용': 974,
#  '챕터': 975,
#  '등등': 976,
#  '불가': 977,
#  '랄': 978,
#  '제외': 979,
#  '시절': 980,
#  '라이브러리': 981,
#  '컷': 982,
#  '리뷰': 983,
#  '멈추': 984,
#  '살짝': 985,
#  '침': 986,
#  '실력': 987,
#  '표현': 988,
#  '모으': 989,
#  '연결': 990,
#  '대충': 991,
#  '어려워서': 992,
#  '유료': 993,
#  '앤': 994,
#  '당': 995,
#  '바뀌': 996,
#  '테': 997,
#  '버림': 998,
#  '으시': 999,
#  '연습': 1000,
#  ...}

# %%
threshold = 2
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 32817
# 등장 빈도가 1번 이하인 희귀 단어의 수: 13878
# 단어 집합에서 희귀 단어의 비율: 42.28905750068562
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 1.2254607619437832

# %%
# 전체 단어 개수 중 빈도수 2이하인 단어 개수는 제거.
# 0번 패딩 토큰과 1번 OOV 토큰을 고려하여 +2
vocab_size = total_cnt - rare_cnt + 2
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합의 크기 : 18941

# %%
tokenizer = Tokenizer(vocab_size, oov_token = 'OOV') 
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
print(X_train[:3])
# Out:
# [[495, 7, 35, 87, 149, 2429, 599, 26, 8, 70, 47, 235, 111, 38, 44, 52], [161, 300, 18, 20, 63, 3582, 985, 6, 56], [7, 17, 1476, 4]]

# %%
print(X_test[:3])
# Out:
# [[728, 34, 16, 431, 52, 106, 132, 99, 6461, 453], [4527, 687, 835, 712, 792, 108, 4, 1779, 95, 370, 3518, 81, 558, 1904, 4189, 262, 169, 61, 25, 363, 35, 87, 974, 19, 6294, 6422], [1792, 806, 685, 49, 23, 349]]

# %%
print('리뷰의 최대 길이 :',max(len(review) for review in X_train))
print('리뷰의 평균 길이 :',sum(map(len, X_train))/len(X_train))
plt.hist([len(review) for review in X_train], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 64
# 리뷰의 평균 길이 : 15.115951894712957

# %%
def below_threshold_len(max_len, nested_list):
  count = 0
  for sentence in nested_list:
    if(len(sentence) <= max_len):
        count = count + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (count / len(nested_list))*100))

# %%
max_len = 60
below_threshold_len(max_len, X_train)
# Out:
# 전체 샘플 중 길이가 60 이하인 샘플의 비율: 99.99599567532935

# %%
X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)

# %%
import re
from tensorflow.keras.layers import Embedding, Dense, LSTM, Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

emb_dims = 100
x = layers.Input(shape = max_len)
y = layers.Embedding(vocab_size, emb_dims)(x)
y = layers.Bidirectional(layers.GRU(128, return_sequences=True))(y)
y = layers.Bidirectional(layers.GRU(128, return_sequences=True))(y)
y = layers.GRU(64, return_sequences=True)(y)
y = layers.GlobalAveragePooling1D()(y)
y = layers.Dense(1, activation = 'sigmoid')(y)

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

model = models.Model(x,y)
model.compile(loss = 'binary_crossentropy',
              optimizer = 'rmsprop',
              metrics = ['acc'])

# %%
model.summary()
# Out:
# Model: "model_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_30 (InputLayer)       [(None, 60)]              0
#
#  embedding_29 (Embedding)    (None, 60, 100)           1894100
#
#  bidirectional_4 (Bidirectio  (None, 60, 256)          176640
#  nal)
#
#  bidirectional_5 (Bidirectio  (None, 60, 256)          296448
#  nal)
#
#  gru_39 (GRU)                (None, 60, 64)            61824
#
#  global_average_pooling1d_7   (None, 64)               0
#  (GlobalAveragePooling1D)
#
#  dense_25 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 2,429,077
# Trainable params: 2,429,077
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=15, callbacks=[es, mc], batch_size=256, validation_split=0.2)
# Out:
# Epoch 1/15
# 235/235 [==============================] - ETA: 0s - loss: 0.5540 - acc: 0.7117
# Epoch 1: val_acc improved from -inf to 0.76582, saving model to best_model.h5
# 235/235 [==============================] - 19s 46ms/step - loss: 0.5540 - acc: 0.7117 - val_loss: 0.4881 - val_acc: 0.7658
# Epoch 2/15
# 235/235 [==============================] - ETA: 0s - loss: 0.4489 - acc: 0.7962
# Epoch 2: val_acc improved from 0.76582 to 0.78590, saving model to best_model.h5
# 235/235 [==============================] - 9s 39ms/step - loss: 0.4489 - acc: 0.7962 - val_loss: 0.4588 - val_acc: 0.7859
# Epoch 3/15
# 235/235 [==============================] - ETA: 0s - loss: 0.4136 - acc: 0.8156
# Epoch 3: val_acc improved from 0.78590 to 0.78764, saving model to best_model.h5
# 235/235 [==============================] - 9s 39ms/step - loss: 0.4136 - acc: 0.8156 - val_loss: 0.4731 - val_acc: 0.7876
# Epoch 4/15
# 235/235 [==============================] - ETA: 0s - loss: 0.3876 - acc: 0.8290
# Epoch 4: val_acc did not improve from 0.78764
# 235/235 [==============================] - 9s 39ms/step - loss: 0.3876 - acc: 0.8290 - val_loss: 0.4893 - val_acc: 0.7804
# Epoch 5/15
# 235/235 [==============================] - ETA: 0s - loss: 0.3685 - acc: 0.8404
# Epoch 5: val_acc did not improve from 0.78764
# 235/235 [==============================] - 9s 39ms/step - loss: 0.3685 - acc: 0.8404 - val_loss: 0.4700 - val_acc: 0.7834
# Epoch 6/15
# 235/235 [==============================] - ETA: 0s - loss: 0.3514 - acc: 0.8484
# Epoch 6: val_acc improved from 0.78764 to 0.79225, saving model to best_model.h5
# 235/235 [==============================] - 9s 40ms/step - loss: 0.3514 - acc: 0.8484 - val_loss: 0.4563 - val_acc: 0.7922
# Epoch 7/15
# 235/235 [==============================] - ETA: 0s - loss: 0.3328 - acc: 0.8588
# Epoch 7: val_acc did not improve from 0.79225
# 235/235 [==============================] - 9s 39ms/step - loss: 0.3328 - acc: 0.8588 - val_loss: 0.5054 - val_acc: 0.7805
# Epoch 8/15
# 235/235 [==============================] - ETA: 0s - loss: 0.3112 - acc: 0.8691
# Epoch 8: val_acc did not improve from 0.79225
# 235/235 [==============================] - 9s 39ms/step - loss: 0.3112 - acc: 0.8691 - val_loss: 0.4955 - val_acc: 0.7803
# Epoch 9/15
# 235/235 [==============================] - ETA: 0s - loss: 0.2891 - acc: 0.8802
# Epoch 9: val_acc did not improve from 0.79225
# 235/235 [==============================] - 9s 39ms/step - loss: 0.2891 - acc: 0.8802 - val_loss: 0.5437 - val_acc: 0.7820
# Epoch 10/15
# 235/235 [==============================] - ETA: 0s - loss: 0.2654 - acc: 0.8903
# Epoch 10: val_acc did not improve from 0.79225
# 235/235 [==============================] - 9s 39ms/step - loss: 0.2654 - acc: 0.8903 - val_loss: 0.6010 - val_acc: 0.7758
# Epoch 10: early stopping

# %%
loaded_model = load_model('best_model.h5')
print("테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, y_test)[1]))
# Out:
# 781/781 [==============================] - 8s 8ms/step - loss: 0.4634 - acc: 0.7869
# 테스트 정확도: 0.7869

# %%
def sentiment_predict(new_sentence):
  new_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','', new_sentence)
  new_sentence = mecab.morphs(new_sentence) # 토큰화
  new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
  encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
  pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
  score = float(loaded_model.predict(pad_new)) # 예측
  if(score > 0.5):
    print("{:.2f}% 확률로 긍정 리뷰입니다.".format(score * 100))
  else:
    print("{:.2f}% 확률로 부정 리뷰입니다.".format((1 - score) * 100))

# %%
sentiment_predict('재미없다가 있습니다')
# Out:
# 87.90% 확률로 부정 리뷰입니다.

# %%
sentiment_predict('재미없었는데 있었다가 다시 없었다가 결국 있었습니다')
# Out:
# 90.00% 확률로 부정 리뷰입니다.
